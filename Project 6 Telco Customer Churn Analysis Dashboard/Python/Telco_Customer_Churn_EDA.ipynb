# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel("telco.xlsx")
df.head()
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# 2                     3  United States  California  ...
# 3                     1  United States  California  ...
# 4                     1  United States  California  ...
#
#   Total Extra Data Charges  Total Long Distance Charges  Total Revenue  \
# 0                       20                         0.00          59.65
# ...

# %%
df.shape
# Out:
# (7043, 50)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   str
#  1   Gender                             7043 non-null   str
#  2   Age                                7043 non-null   int64
#  3   Under 30                           7043 non-null   str
#  4   Senior Citizen                     7043 non-null   str
#  5   Married                            7043 non-null   str
#  6   Dependents                         7043 non-null   str
#  7   Number of Dependents               7043 non-null   int64
#  8   Country                            7043 non-null   str
#  9   State                              7043 non-null   str
#  10  City                               7043 non-null   str
#  11  Zip Code                           7043 non-null   int64
# ...

# %%
df.nunique()
# Out:
# Customer ID                          7043
# Gender                                  2
# Age                                    62
# Under 30                                2
# Senior Citizen                          2
# Married                                 2
# Dependents                              2
# Number of Dependents                   10
# Country                                 1
# State                                   1
# City                                 1106
# Zip Code                             1626
# Latitude                             1626
# Longitude                            1625
# Population                           1569
# Quarter                                 1
# Referred a Friend                       2
# Number of Referrals                    12
# Tenure in Months                       72
# Offer                                   5
# Phone Service                           2
# Avg Monthly Long Distance Charges    3584
# ...

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Churn Reason                         5174
# Churn Category                       5174
# Offer                                3877
# Internet Type                        1526
# Senior Citizen                          0
# Married                                 0
# Age                                     0
# Under 30                                0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Dependents                              0
# Number of Dependents                    0
# Customer ID                             0
# Gender                                  0
# Number of Referrals                     0
# Referred a Friend                       0
# Quarter                                 0
# Population                              0
# ...

# %%
pd.crosstab(df['Customer Status'], df['Churn Reason'], dropna = False)
# Out:
# Churn Reason     Attitude of service provider  Attitude of support person  \
# Customer Status
# Churned                                    94                         220
# Joined                                      0                           0
# Stayed                                      0                           0
#
# Churn Reason     Competitor had better devices  Competitor made better offer  \
# Customer Status
# Churned                                    313                           311
# Joined                                       0                             0
# Stayed                                       0                             0
#
# Churn Reason     Competitor offered higher download speeds  \
# Customer Status
# Churned                                                100
# Joined                                                   0
# Stayed                                                   0
#
# ...

# %%
pd.crosstab(df['Customer Status'], df['Churn Category'], dropna = False)
# Out:
# Churn Category   Attitude  Competitor  Dissatisfaction  Other  Price   NaN
# Customer Status
# Churned               314         841              303    200    211     0
# Joined                  0           0                0      0      0   454
# Stayed                  0           0                0      0      0  4720

# %%
pd.crosstab(df['Customer Status'], df['Offer'], dropna = False)
# Out:
# Offer            Offer A  Offer B  Offer C  Offer D  Offer E   NaN
# Customer Status
# Churned               35      101       95      161      426  1051
# Joined                 0        0        0        0      175   279
# Stayed               485      723      320      441      204  2547

# %%
[col for col in df.columns if 'Charge' in col]
# Out:
# ['Avg Monthly Long Distance Charges',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges']

# %%
[col for col in df.columns if 'Revenue' in col]
# Out:
# ['Total Revenue']

# %%
[col for col in df.columns if 'CLTV' in col]
# Out:
# ['CLTV']

# %%
df.duplicated("Customer ID").sum()
# Out:
# np.int64(0)

# %%
pd.crosstab(df["Customer ID"], df["Internet Type"], dropna = False)
# Out:
# Internet Type  Cable  DSL  Fiber Optic  NaN
# Customer ID
# 0002-ORFBO         1    0            0    0
# 0003-MKNFE         1    0            0    0
# 0004-TLHLJ         0    0            1    0
# 0011-IGKFF         0    0            1    0
# 0013-EXCHZ         0    0            1    0
# ...              ...  ...          ...  ...
# 9987-LUTYD         0    1            0    0
# 9992-RRAMN         0    0            1    0
# 9992-UJOEL         0    1            0    0
# 9993-LHIEB         1    0            0    0
# 9995-HOTOH         1    0            0    0
#
# [7043 rows x 4 columns]

# %%
pd.crosstab(df["Customer ID"], df["Internet Service"], dropna = False)
# Out:
# Internet Service  No  Yes
# Customer ID
# 0002-ORFBO         0    1
# 0003-MKNFE         0    1
# 0004-TLHLJ         0    1
# 0011-IGKFF         0    1
# 0013-EXCHZ         0    1
# ...               ..  ...
# 9987-LUTYD         0    1
# 9992-RRAMN         0    1
# 9992-UJOEL         0    1
# 9993-LHIEB         0    1
# 9995-HOTOH         0    1
#
# [7043 rows x 2 columns]
